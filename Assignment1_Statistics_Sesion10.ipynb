# %% [markdown]
# ## Problem Statement 1:
# You survey households in your area to find the average rent they are paying. Find the standard deviation from the following data:
# $1550, $1700, $900, $850, $1000, $950.

# %%
def mean(arr):
    return sum(arr)/len(arr)

def variance(arr):
    variance = 0.0
    from math import sqrt
    mean = find_mean(arr)
    variance = sum((x - mean)**2 for x in arr) / (len(arr)-1)
    return variance

def std_dev(arr):
    return find_variance(arr)**0.5

arr = [1550,1700,900,850,1000,950]

# %%
from math import sqrt
print("Calculation using custom method")
print ("Mean " + str(round(mean(arr),3)))
print ("variance " + str(round(variance(arr),3)))
print("std_dev " + str(round(std_dev(arr),3)))
# Out:
# Calculation using custom method
# Mean 1158.333
# variance 135416.667
# std_dev 367.99

# %% [markdown]
# ### OR

# %%
print("Calculation using statistics library")
import statistics as stat
print(str("Mean " + str(round(stat.mean(arr),3))))
print(str("Variance " + str(round(stat.variance(arr),3))))
print(str("std_dev " + str(round(stat.stdev(arr),3))))
# Out:
# Calculation using statistics library
# Mean 1158.333
# Variance 135416.667
# std_dev 367.99

# %%
#---------------------------------------------------------#

# %% [markdown]
# ## Problem Statement 2:
# Find the variance for the following set of data representing trees in California (heights in feet):
# 3, 21, 98, 203, 17, 9

# %%
def mean(arr):
    return sum(arr)/len(arr)

def variance(arr):
    variance = 0.0
    from math import sqrt
    mean = find_mean(arr)
    variance = sum((x - mean)**2 for x in arr) / (len(arr)-1)
    return variance

def std_dev(arr):
    return find_variance(arr)**0.5

arr1 = [3,21,98,203,17,9]

from math import sqrt
print("Calculation using custom method")
print ("Mean " + str(round(mean(arr1),3)))
print ("variance " + str(round(variance(arr1),3)))
print("std_dev " + str(round(std_dev(arr1),3)))
# Out:
# Calculation using custom method
# Mean 58.5
# variance 6219.9
# std_dev 78.866

# %% [markdown]
# ## OR

# %%
print("Calculation using statistics library")
import statistics as stat
print(str("Mean " + str(round(stat.mean(arr1),3))))
print(str("Variance " + str(round(stat.variance(arr1),3))))
print(str("std_dev " + str(round(stat.stdev(arr1),3))))
# Out:
# Calculation using statistics library
# Mean 58.5
# Variance 6219.9
# std_dev 78.866

# %%
#------------------------------------------------------#

# %% [markdown]
# ## Problem Statement 3:
# In a class on 100 students, 80 students passed in all subjects, 10 failed in one subject, 7 failed in two subjects and 3 failed in three subjects. Find the probability distribution of the variable for number of subjects a student from the given class has failed in.

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ('X=0', 'X=1', 'X=2', 'X=3')
y_pos = np.arange(len(objects))
performance = [80,10,7,3]
prob_X=[.80,.1,.07,.03]

plt.bar(y_pos,prob_X, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Probability of Failure in Class')
plt.title('Probability distribution of Failure:-X=Count of exam failed')
plt.show()

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Failures in Class')
plt.title('Distribution Count of Failures in Class :-X=Count of exam failed')

plt.show()

# %%
#-------------------------------------------------#
